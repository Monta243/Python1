# %% [markdown]
# <a href="https://colab.research.google.com/github/Monta243/Data-Science-and-Machine-Learning-Camp-Beginner-Level-/blob/main/Python_%D8%AA%D8%AD%D8%AF%D9%8A_%D9%85%D8%B3%D8%A7%D8%B1_%D8%A8%D8%A7%D8%B3%D8%AA%D8%AE%D8%AF%D8%A7%D9%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Read data from CSV file
data = pd.read_csv('/content/تحدي_تحليل_البيانات_باستخدام_البايثون_🐍.csv')
data
# Out:
#            id                                           keywords
# 0         862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1        8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2       15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3       31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4       11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...       ...                                                ...
# 46414  439050             [{'id': 10703, 'name': 'tragic love'}]
# 46415  111109  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
# 46416   67758                                                 []
# 46417  227506                                                 []
# 46418  461257                                                 []
#
# [46419 rows x 2 columns]

# %%
data.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
df = pd.DataFrame(data)

rows_to_drop = df[df['keywords'] == '[]'].index

df.drop(rows_to_drop, axis=0, inplace=True)

# %%
df
# Out:
#            id                                           keywords
# 0         862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1        8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2       15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3       31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4       11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...       ...                                                ...
# 46409   84419  [{'id': 9748, 'name': 'revenge'}, {'id': 9826,...
# 46410  390959            [{'id': 224180, 'name': 'blair witch'}]
# 46411  289923  [{'id': 616, 'name': 'witch'}, {'id': 2035, 'n...
# 46414  439050             [{'id': 10703, 'name': 'tragic love'}]
# 46415  111109  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
#
# [31624 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31624 entries, 0 to 46415
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        31624 non-null  int64
#  1   keywords  31624 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 741.2+ KB

# %%
df.duplicated().sum()
# Out:
# 532

# %%
df.drop_duplicates()
# Out:
#            id                                           keywords
# 0         862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1        8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2       15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3       31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4       11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...       ...                                                ...
# 46409   84419  [{'id': 9748, 'name': 'revenge'}, {'id': 9826,...
# 46410  390959            [{'id': 224180, 'name': 'blair witch'}]
# 46411  289923  [{'id': 616, 'name': 'witch'}, {'id': 2035, 'n...
# 46414  439050             [{'id': 10703, 'name': 'tragic love'}]
# 46415  111109  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
#
# [31092 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# id          0
# keywords    0
# dtype: int64

# %%
df.describe()
# Out:
#                   id
# count   31624.000000
# mean    96325.953611
# std    110407.591172
# min         2.000000
# 25%     18697.500000
# 50%     46085.000000
# 75%    128614.250000
# max    468707.000000

# %%
# Save the cleaned dataset to the new CSV file.
df.to_csv('تنظيف_تحدي_تحليل_البيانات_باستخدام_البايثون.csv', index=False)
